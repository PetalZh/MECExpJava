# %%
import matplotlib.pyplot as plt
import math

def process():
    dict = {}
    f = open("result.txt")
    lines = f.readlines()
    for line in lines:
        c = line.split(",") 
        #c[0]: method, c[1]: theta, c[2]: input size(bs num) 
        #c[3]: en num, c[4]: cost, c[5]: time
        
        method = c[0]
        theta = c[1]
        bs_num = c[2]
        
        c[5] = c[5].replace("\n","")
        if theta in dict:
            if method in dict[theta]:
                if bs_num in dict[theta][method]:
                    dict[theta][method][bs_num].append([c[3], c[4], c[5]])
                else:
                    dict[theta][method].update({bs_num: [c[3], c[4], c[5]]})
            else:
                dict[theta].update({method: {}})
        else:
            dict.update({theta: {}})
            
    f.close()
    return dict
dict = process()
print(dict)
# Out:
# {'30.0': {'greedy': {'200': ['79', '41800', '0.157', ['79', '41800', '0.109'], ['79', '41800', '0.098'], ['79', '41800', '0.095'], ['79', '41800', '0.095'], ['79', '41800', '0.099'], ['79', '41800', '0.099'], ['79', '41800', '0.106'], ['79', '41800', '0.105'], ['79', '41800', '0.102']], '300': ['102', '54600', '0.284', ['102', '54600', '0.255'], ['102', '54600', '0.253'], ['102', '54600', '0.254'], ['102', '54600', '0.257'], ['102', '54600', '0.258'], ['102', '54600', '0.265'], ['102', '54600', '0.269'], ['102', '54600', '0.259'], ['102', '54600', '0.258']], '400': ['128', '69000', '0.653', ['128', '69000', '0.52'], ['128', '69000', '0.519'], ['128', '69000', '0.52'], ['128', '69000', '0.511'], ['128', '69000', '0.532'], ['128', '69000', '0.589'], ['128', '69000', '0.523'], ['128', '69000', '0.52'], ['128', '69000', '0.521']], '500': ['142', '77300', '1.041', ['142', '77300', '0.861'], ['142', '77300', '0.867'], ['142', '77300', '0.865'], ['142', '77300', '0.86'], ['142', '77300', '0.861'], ['142', '77300', '0.924'], ['142', '77300', '0.86'], ['142', '77300', '0.861'], ['142', '77300', '0.868']], '600': ['156', '86000', '1.406', ['156', '86000', '1.226'], ['156', '86000', '1.224'], ['156', '86000', '1.214'], ['156', '86000', '1.217'], ['156', '86000', '1.219'], ['156', '86000', '1.258'], ['156', '86000', '1.219'], ['156', '86000', '1.223'], ['156', '86000', '1.323']], '800': ['172', '97400', '2.453', ['172', '97400', '2.301'], ['172', '97400', '2.283'], ['172', '97400', '2.295'], ['172', '97400', '2.283'], ['172', '97400', '2.284'], ['172', '97400', '2.367'], ['172', '97400', '2.293'], ['172', '97400', '2.308'], ['172', '97400', '2.299']], '1000': ['188', '109300', '3.793', ['188', '109300', '3.533'], ['188', '109300', '3.537'], ['188', '109300', '3.531'], ['188', '109300', '3.567'], ['188', '109300', '3.57'], ['188', '109300', '3.823'], ['188', '109300', '3.551'], ['188', '109300', '3.559'], ['188', '109300', '3.572']], '1500': ['223', '136900', '9.642', ['223', '136900', '8.691'], ['223', '136900', '8.701'], ['223', '136900', '8.838'], ['223', '136900', '8.71'], ['223', '136900', '8.845'], ['223', '136900', '8.894'], ['223', '136900', '8.87'], ['223', '136900', '8.746'], ['223', '136900', '8.73']], '2000': ['239', '154500', '16.55', ['239', '154500', '15.099'], ['239', '154500', '15.114'], ['239', '154500', '15.107'], ['239', '154500', '15.114'], ['239', '154500', '15.54'], ['239', '154500', '15.191'], ['239', '154500', '15.179'], ['239', '154500', '15.226'], ['239', '154500', '15.192']], '2500': ['261', '175900', '23.956', ['261', '175900', '23.935'], ['261', '175900', '23.949'], ['261', '175900', '23.959'], ['261', '175900', '23.998'], ['261', '175900', '23.918'], ['261', '175900', '24.136'], ['261', '175900', '24.033'], ['261', '175900', '24.084'], ['261', '175900', '24.13']], '3000': ['264', '183100', '29.782', ['264', '183100', '29.708'], ['264', '183100', '29.713'], ['264', '183100', '29.827'], ['264', '183100', '30.455'], ['264', '183100', '31.754'], ['264', '183100', '29.9'], ['264', '183100', '29.897'], ['264', '183100', '29.87'], ['264', '183100', '29.736']], '100': ['47', '24100', '0.018', ['47', '24100', '0.018'], ['47', '24100', '0.018'], ['47', '24100', '0.018'], ['47', '24100', '0.019'], ['47', '24100', '0.018'], ['47', '24100', '0.018'], ['47', '24100', '0.021'], ['47', '24100', '0.017']]}, 'greedy_new': {'200': ['79', '41500', '0.162', ['79', '41500', '0.117'], ['79', '41500', '0.129'], ['79', '41500', '0.11'], ['79', '41500', '0.123'], ['79', '41500', '0.101'], ['79', '41500', '0.114'], ['79', '41500', '0.111'], ['79', '41500', '0.109'], ['79', '41500', '0.119']], '300': ['101', '53700', '0.305', ['101', '53600', '0.237'], ['101', '53600', '0.243'], ['101', '53600', '0.242'], ['101', '53600', '0.237'], ['101', '53600', '0.24'], ['101', '53600', '0.261'], ['101', '53600', '0.242'], ['101', '53600', '0.238'], ['101', '53600', '0.244']], '400': ['127', '67700', '0.625', ['127', '67700', '0.464'], ['127', '6770 ...

# %%
def getStatistic(dict):
    for t in dict:
        for m in dict[t]:
            for bs in dict[t][m]:
                en = 0
                cost = 0
                time = 0
                for value in dict[t][m][bs]:
                    en = en + int(value[0])
                    #cost = cost + int(value[1])
                    #time = time + float(value[2])
                en = math.ceil(en / len(dict[t][m][bs]))
                cost = math.ceil(cost / len(dict[t][m][bs]))
                time = math.ceil(time / len(dict[t][m][bs]))
                
                dict[t][m][bs] = [en, cost, time]

getStatistic(dict)
print(dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/7h/4_bttzz14kn2tdgj445fvtvc0000gn/T/ipykernel_5777/426396830.py in <module>
#      16                 dict[t][m][bs] = [en, cost, time]
#      17
# ---> 18 getStatistic(dict)
#      19 print(dict)
#
# /var/folders/7h/4_bttzz14kn2tdgj445fvtvc0000gn/T/ipykernel_5777/426396830.py in getStatistic(dict)
#       7                 time = 0
#       8                 for value in dict[t][m][bs]:
# ----> 9                     en = en + int(value[0])
#      10                     #cost = cost + int(value[1])
#      11                     #time = time + float(value[2])
#
# TypeError: 'int' object is not subscriptable
